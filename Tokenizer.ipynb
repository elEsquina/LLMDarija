# %%
import pandas as pd
import unicodedata
import re

# %%
df = pd.read_csv('assets/data-LID/train_Darija_LID.csv')
df.head()
# Out:
#   dialect                                               text  \
# 0  Jordan         بابا .. بابا .. شوف اديش في عروض على السفر
# 1  Jordan                                      يييي ما أزنخك
# 2  Jordan                        الكل يروح ينام والصباح رباح
# 3  Jordan                                الكابتن حابة تشوفك!
# 4  Jordan  تخيل لو عزمت كل الصف ما عداك أنت، شو بيكون شعورك؟
#
#               source  label  nwords
# 0  guymorlan/levanti  other      10
# 1  guymorlan/levanti  other       3
# 2  guymorlan/levanti  other       5
# 3  guymorlan/levanti  other       3
# 4  guymorlan/levanti  other      11

# %%
ARABIC_DIACRITICS = re.compile(r'[\u0610-\u061A\u064B-\u065F\u06D6-\u06ED\u200f]')
TATWEEL = 'ـ'
EASTERN_AR_NUMS = str.maketrans("۰۱۲۳۴۵۶۷۸۹", "0123456789")

def clean_darija(text):
    text = str(text)
    text = unicodedata.normalize("NFKC", text)             # Normalize Unicode
    text = text.translate(EASTERN_AR_NUMS)                 # Convert Eastern Arabic numerals to 0–9
    text = text.replace(TATWEEL, '')                       # Remove Tatweel
    text = ARABIC_DIACRITICS.sub('', text)                 # Remove diacritics
    text = re.sub(r'[^\u0600-\u06FF\u0750-\u077F\u08A0-\u08FF'
                  r'\uFB50-\uFDFF\uFE70-\uFEFF\n0-9 ]+', '', text)  # Keep Arabic, numbers, space, \n
    text = re.sub(r'[^\S\n]+', ' ', text).strip()          # Normalize spaces, preserve \n
    return text

# %%
df = df[df['label'] == 'ary']
corpus = df['text'].apply(clean_darija).tolist()

# %%
del df

# %%
from utils.BPE import BytePairEncoding

encoder = BytePairEncoding(num_merges=100)

# %%
encoder.train(corpus)
# Out:
# Merge 1: ('ا', 'ل')
# Merge 2: ('ي', '</w>')
# Merge 3: ('ة', '</w>')
# Merge 4: ('ا', '</w>')
# Merge 5: ('ن', '</w>')
# Merge 6: ('د', '</w>')
# Merge 7: ('د', 'ي')
# Merge 8: ('ش', '</w>')
# Merge 9: ('ه', 'ا')
# Merge 10: ('ر', '</w>')
# Merge 11: ('؟', '</w>')
# Merge 12: ('و', '</w>')
# Merge 13: ('ت', '</w>')
# Merge 14: ('ها', 'د</w>')
# Merge 15: ('ك', '</w>')
# Merge 16: ('ال', '</w>')
# Merge 17: ('ه', '</w>')
# Merge 18: ('ا', 'ش</w>')
# Merge 19: ('ر', 'ا')
# Merge 20: ('ف', '</w>')
# Merge 21: ('،', '</w>')
# Merge 22: ('ل', 'ي')
# Merge 23: ('ش', 'ي</w>')
# Merge 24: ('ل', '</w>')
# Merge 25: ('ب', '</w>')
# Merge 26: ('ال', 'م')
# Merge 27: ('م', '</w>')
# Merge 28: ('دي', 'ال</w>')
# Merge 29: ('ن', 'ي</w>')
# Merge 30: ('ف', 'ي')
# Merge 31: ('ك', 'ي')
# Merge 32: ('خ', 'ا')
# Merge 33: ('د', 'ا')
# Merge 34: ('ى', '</w>')
# Merge 35: ('ع', 'ل')
# Merge 36: ('ك', 'ت')
# Merge 37: ('ب', 'ا')
# Merge 38: ('ك', 'ا')
# Merge 39: ('خا', 'ص')
# Merge 40: ('ال', 'ل')
# Merge 41: ('ي', 'ا')
# Merge 42: ('ن', 'ا</w>')
# Merge 43: ('م', 'ا')
# Merge 44: ('و', 'ا')
# Merge 45: ('ر', 'ي')
# Merge 46: ('غ', 'ي')
# Merge 47: ('ز', 'ا')
# Merge 48: ('ب', 'ي')
# Merge 49: ('ع', '</w>')
# Merge 50: ('ب', 'زا')
# Merge 51: ('ع', 'ا')
# Merge 52: ('س', '</w>')
# Merge 53: ('را', 'ه</w>')
# Merge 54: ('و', 'ن</w>')
# Merge 55: ('ن', 'ا')
# Merge 56: ('ل', 'ا')
# Merge 57: ('الل', 'ه</w>')
# Merge 58: ('ي', 'ة</w>')
# Merge 59: ('ن', 'ت')
# Merge 60: ('م', 'ن</w>')
# Merge 61: ('ع', 'ن')
# Merge 62: ('ال', 'ت')
# Merge 63: ('عل', 'ى</w>')
# Merge 64: ('ش', 'و')
# Merge 65: ('ر', 'ة</w>')
# Merge 66: ('بزا', 'ف</w>')
# Merge 67: ('ب', 'غي')
# Merge 68: ('ي', 'ن</w>')
# Merge 69: ('ر', 'و')
# Merge 70: ('ال', 'س')
# Merge 71: ('ة', '؟</w>')
# Merge 72: ('ال', 'ك')
# Merge 73: ('ق', '</w>')
# Merge 74: ('ح', '</w>')
# Merge 75: ('ن', 'ق')
# Merge 76: ('ت', 'ي</w>')
# Merge 77: ('ال', 'ط')
# Merge 78: ('بغي', 'ت</w>')
# Merge 79: ('ال', 'ب')
# Merge 80: ('خاص', 'ني</w>')
# Merge 81: ('ز', 'يا')
# Merge 82: ('و', 'ن')
# Merge 83: ('ح', 'ال</w>')
# Merge 84: ('ب', 'ة</w>')
# Merge 85: ('ل', 'ل')
# Merge 86: ('م', 'زيا')
# Merge 87: ('م', 'ة</w>')
# Merge 88: ('ال', 'ح')
# Merge 89: ('ك', 'ن')
# Merge 90: ('ال', 'ص')
# Merge 91: ('د', 'و')
# Merge 92: ('ال', 'ش')
# Merge 93: ('ع', 'ر')
# Merge 94: ('ش', 'حال</w>')
# Merge 95: ('غ', 'ا')
# Merge 96: ('ال', 'ج')
# Merge 97: ('ح', 'ا')
# Merge 98: ('ال', 'ق')
# Merge 99: ('ف', 'ا')
# Merge 100: ('ر', 'ج')
# {'ال والي</w>': 27,
#  'دا ر</w>': 1233,
#  'خ ط ا ب</w>': 32,
#  'م ه م</w>': 208,
#  'البا ر ح</w>': 535,
#  'خاصني</w>': 7669,
#  'نت ق ا ت ل</w>': 24,
#  'على</w>': 11269,
#  'هاد</w>': 32920,
#  'البي ر م ي</w>': 49,
#  'با غي</w>': 740,
#  'نت عل م</w>': 1002,
#  'ل ون ك لي</w>': 6,
#  'باش</w>': 12417,
#  'ن خ د م</w>': 344,
#  'م ع</w>': 2505,
#  'الش ر كا ت</w>': 99,
#  'ال دو لية</w>': 11,
#  'أ نا</w>': 1360,
#  'ط الب</w>': 39,
#  'في</w>': 9453,
#  'الج ا م ع ة</w>': 107,
#  'خ ص ني</w>': 1326,
#  'ن ر ت اش</w>': 1,
#  'من</w>': 9265,
#  'دا با</w>': 2119,
#  'نق د ر</w>': 1606,
#  'ن و ص ل</w>': 243,
#  'لل ش ه ر</w>': 6,
#  'الج ا ي</w>': 158,
#  'واش</w>': 16305,
#  'كت عر ف</w>': 1124,
#  'شي</w>': 19038,
#  'ديال</w>': 22665,
#  'اللي</w>': 6566,
#  'م و ث و ق ة؟</w>': 6,
#  'أ ش ن و</w>': 157,
#  'وا ق ع ؟</w>': 82,
#  'ك ل</w>': 1406,
#  'وا ح د</w>': 3525,
#  'ر ز ق ه</w>': 3,
#  'م كت و ب</w>': 34,
#  'نت لا ق ا و</w>': 138,
#  'فالس ا ع ة</w>': 17,
#  'خاص نا</w>': 4635,
#  'ن ص ل ح و</w>': 118,
#  'ال علا ق ة</w>': 24,
#  'بين</w>': 323,
#  'الش ع ب</w>': 192,
#  'و</w>': 6444,
#  'الح ك و مة</w>': 694,
#  'م بغي ت ش</w>': 110,
#  'ن ص ب غ </w>': 77,
#  'ش عري ،</w>': 46,
#  'بغيت</w>': 7911,
#  'ن خ لي</w>': 55,
#  'الل ون</w>': 118,
#  'ديال و</w>': 702,
#  'الط بي ع ي</w>': 9,
#  'الل ع ب</w>': 595,
#  'كي ف ر غ </w>': 3,
#  'ال د ما غ </w>': 45,
#  'ال ه م</w>': 140,
#  'عن دي</w>': 2925,
#  'ص دا ع</w>': 336,
#  'ال را س ،</w>': 26,
#  'ن دي ر</w>': 2447,
#  'م س ا ج </w>': 87,
#  'شحال</w>': 5745,
#  'غا دي</w>': 3265,
#  'ت ج ي ني</w>': 9,
#  'ال ض ري بة</w>': 416,
#  'ال دا ر ؟</w>': 373,
#  'الط ري ق</w>': 1354,
#  'م س ر ح ة</w>': 12,
#  'مزيا ن</w>': 4463,
#  'و لا</w>': 3720,
#  'في ها</w>': 3093,
#  'الح ف ر ؟</w>': 9,
#  'ما زال</w>': 649,
#  'ال نا س</w>': 2183,
#  'م ر ض ى</w>': 2,
#  'بالك و رونا ،</w>': 1,
#  'الله</w>': 12058,
#  'ي ش ا في ه م</w>': 2,
#  'راه</w>': 13144,
#  'ال ريا ض ة</w>': 486,
#  'كت ب د ل</w>': 10,
#  'الم و رال</w>': 12,
#  'ك ل ما</w>': 2,
#  'ض ح كتي</w>': 3,
#  'ح س ي تي</w>': 17,
#  'بال را ح ة</w>': 7,
#  'خ لي</w>': 517,
#  'البال</w>': 417,
#  'الم و ط و را ت</w>': 2,
#  'ال را س</w>': 279,
#  'ال ف ل و س</w>': 1391,
#  'يالا ه</w>': 133,
#  'س الي ت</w>': 141,
#  'الكت ا ب</w>': 2227,
#  'ما ب ق ي ت ش</w>': 100,
#  'ق ا د</w>': 88,
#  'ن شو ف</w>': 1444,
#  'حا ج ة</w>': 2139,
#  'ا خ ر ى</w>': 51,
#  'ي ح ض ر</w>': 171,
#  'الس لا مة</w>': 341,
#  'ف</w>': 6551,
#  'ط ري ق</w>': 151,
#  'ال خ د مة</w>': 1399,
#  'ي ع م ر ها</w>': 114,
#  'دا ر ،</w>': 46,
#  'الب لا ص ة</w>': 382,
#  'الا ما ن</w>': 28,
#  'اش</w>': 447,
#  'كي ق و ل</w>': 82,
#  'الم ذ ي ع ؟</w>': 1,
#  'ال وا ح د</w>': 594,
#  'كي ق ل ب</w>': 81,
#  'ل ق مة</w>': 4,
#  'ال ع ي ش</w>': 7,
#  'ص ا في</w>': 1046,
#  'الل ع ب ،</w>': 85,
#  'ع ي ي ت</w>': 917,
#  'الس ي د</w>': 430,
#  'عن دو</w>': 965,
#  'ق نا ة</w>': 61,
#  'الي و ت ي و ب</w>': 84,
#  'فاش</w>': 341,
#  'ت س الي</w>': 101,
#  'الا م ت حا نا ت ،</w>': 1,
#  'غ ن ب ق ى</w>': 8,
#  'غي ر</w>': 3153,
#  'م ق ا ب ل</w>': 56,
#  'الكت و بة</w>': 299,
#  'كت ز ل ق</w>': 17,
#  'باللي ل ،</w>': 53,
#  'ر د</w>': 378,
#  'م ي ب ق اش</w>': 12,
#  'ط ما ع</w>': 22,
#  'الس لا م ة ،</w>': 107,
#  'الح ن ش</w>': 62,
#  'با ين</w>': 351,
#  'في ه</w>': 2977,
#  'م س م و م</w>': 6,
#  'مالح</w>': 12,
#  'بزاف</w>': 10670,
#  'الط يا ب</w>': 124,
#  'ي عا في نا</w>': 3,
#  'ال أ م را ض </w>': 32,
#  'ال خا ي بة</w>': 78,
#  'الشو م ي ني</w>': 2,
#  'م و س خ </w>': 21,
#  'بزا ا ف ،</w>': 4,
#  'ش ك ون</w>': 888,
#  'غا ي ت ف ر ع و ؟</w>': 1,
#  'كي ل ه ي</w>': 3,
#  'ب را س و</w>': 13,
#  'ما</w>': 12010,
#  'كي س و ق</w>': 16,
#  'ل ح ت ى</w>': 7,
#  'الم ش ا ك ل</w>': 546,
#  'ي ط ي ح و ش</w>': 2,
#  'الم بي عا ت</w>': 32,
#  'ما ك ر ه ت ش</w>': 142,
#  'ن س م ع</w>': 198,
#  'خ با ر</w>': 169,
#  'ز و ي ن ة</w>': 521,
#  'ال ن ها ر</w>': 330,
#  'دي رو</w>': 30,
#  'عر س</w>': 18,
#  'ك بي ر</w>': 738,
#  'ن ف ر ح و</w>': 9,
#  'م عا ك م</w>': 52,
#  'ن ز ي د</w>': 550,
#  'شو ية</w>': 4274,
#  'ال ع ض لا ت</w>': 24,
#  'عن دي ش</w>': 486,
#  'ال خا ط ر</w>': 198,
#  'نت ف رج </w>': 561,
#  'في ه م</w>': 205,
#  'خا س ني</w>': 11,
#  'نق ل ب</w>': 327,
#  'ك لا ص </w>': 28,
#  'نت ا ع</w>': 10,
#  'ف و ر ما س ي ون</w>': 77,
#  'ف ل و م ي نا ت ي ك</w>': 1,
#  'ن م ش ي و</w>': 471,
#  'ن ص ي دو</w>': 18,
#  'ن ها ر</w>': 386,
#  'فالب ح ر</w>': 36,
#  'م م كن</w>': 981,
#  'ت نق ص </w>': 126,
#  'ال را دي و</w>': 120,
#  'شو ي ة؟</w>': 218,
#  'الم غ ر ب</w>': 390,
#  'خاص و</w>': 627,
#  'ي ز ي د</w>': 71,
#  'ي س ت ث م ر</w>': 3,
#  'فالب ح ث </w>': 15,
#  'ال عل م ي</w>': 154,
#  'ش ك را</w>': 219,
#  'الم س ا ع د ة</w>': 29,
#  'كي ص ا و ب</w>': 57,
#  'البي س يا ت ؟</w>': 4,
#  'الك و لي س ت رو ل</w>': 7,
#  'ط ال ع</w>': 454,
#  'كنت س ن ى</w>': 236,
#  'الك و لي</w>': 4,
#  'ال خا رج ،</w>': 8,
#  'و ص ل</w>': 260,
#  'م زال ؟</w>': 80,
#  'ن بغي ش</w>': 49,
#  'ن ه ض ر ،</w>': 6,
#  'ن غ ل ط </w>': 8,
#  'ي خ ل ف</w>': 105,
#  'علي ك</w>': 1305,
#  'الت خ مال</w>': 10,
#  'الك ون ي ك س ي ون</w>': 581,
#  'ث ق ي ل ة</w>': 172,
#  'بزا ف ،</w>': 2656,
#  'وا ق ي لا</w>': 542,
#  'غ ن دو ز </w>': 10,
#  'ل وا ح د</w>': 135,
#  'آ خ ر</w>': 553,
#  'ما فيا</w>': 13,
#  'ج ه د</w>': 115,
#  'ن م شي</w>': 1652,
#  'ه دو ك</w>': 7,
#  'دي ما</w>': 2539,
#  'م ش ا ك ل ،</w>': 7,
#  'ي ص ب ر</w>': 103,
#  'ج ي را ن ه م</w>': 1,
#  'ما شي</w>': 1627,
#  'ا كت ي ف</w>': 8,
#  'دي س ك و ر د ،</w>': 1,
#  'والي ني</w>': 5,
#  'كا ن ط ل</w>': 1,
#  'م را ت</w>': 32,
#  'ال ف ن</w>': 137,
#  'كي دو خ ني</w>': 11,
#  'ما عن دي ش</w>': 483,
#  'نق را</w>': 732,
#  'الس ا ع ة ،</w>': 15,
#  'ن ز ل</w>': 40,
#  'في ل م</w>': 406,
#  'ف هاد</w>': 2061,
#  'ال و ي كا ن د</w>': 38,
#  'اللا ع ب</w>': 145,
#  'ج ا ب</w>': 41,
#  'ال گ و ل</w>': 2,
#  'وا عر</w>': 469,
#  'ن س و ل</w>': 184,
#  'الم حا م ي</w>': 143,
#  'ديالي</w>': 2914,
#  'ق ب ل</w>': 1573,
#  'م ن و ق ع</w>': 1,
#  'كت خ ل ص وا</w>': 35,
#  'لل ع مال</w>': 44,
#  'ديالك م</w>': 149,
#  'فالش ه ر ؟</w>': 71,
#  'را ني</w>': 618,
#  'كن و ف ر</w>': 1,
#  'ب شو ية</w>': 319,
#  'ن ح ج </w>': 1,
#  'إ ن</w>': 132,
#  'ش ا ء </w>': 360,
#  'ن ب ر د</w>': 14,
#  'ا ت ا ي</w>': 370,
#  'عا د</w>': 328,
#  'ن ك ب و</w>': 1,
#  'مالي</w>': 149,
#  'ق ري ت</w>': 212,
#  'ف ه م ت</w>': 283,
#  'ال في ل م</w>': 715,
#  'ا ح س ن</w>': 469,
#  'با ق ا</w>': 120,
#  'فال نت ي ج ة؟</w>': 1,
#  'ن دي رو</w>': 1215,
#  'ط ل ب</w>': 147,
#  'ر خ ص ة</w>': 93,
#  'الب نا ء </w>': 82,
#  'فالب ل دية</w>': 12,
#  'مالك</w>': 847,
#  'م ص د ع</w>': 27,
#  'را س ك</w>': 545,
#  'ب هاد</w>': 379,
#  'ال عل و م ،</w>': 40,
#  'س ي ر</w>': 637,
#  'ت ر ت ا ح</w>': 66,
#  'ك دي ري</w>': 53,
#  'ح ما م</w>': 125,
#  'ز ي ت</w>': 192,
#  'ل ش عر ك ؟</w>': 6,
#  'نا ق ص ني</w>': 2,
#  'د</w>': 3106,
#  'الم ل ح</w>': 65,
#  'خاص ك</w>': 2428,
#  'ت ب ق ى</w>': 155,
#  'ت ق را</w>': 314,
#  'و ت ط و ر</w>': 1,
#  'را س ك ،</w>': 54,
#  'ال ز ما ن</w>': 486,
#  'ال عل م</w>': 284,
#  'س لا ح</w>': 19,
#  'غ دي</w>': 125,
#  'نت ع ش ا و</w>': 71,
#  'ال ى</w>': 93,
#  'غ ل ب نا ك</w>': 1,
#  'الل ع ب ة؟</w>': 173,
#  'ها دا ك</w>': 1106,
#  'ال ر ب ح</w>': 93,
#  'الس ري ع</w>': 9,
#  'ق را</w>': 88,
#  'ليا</w>': 5892,
#  'عا فا ك</w>': 969,
#  'خ ف ت</w>': 91,
#  'ن ك ون</w>': 265,
#  'غي ر ت</w>': 3,
#  'فال ث من</w>': 50,
#  'ب ر كا</w>': 11,
#  'ال و ق ت</w>': 1628,
#  'م ش ا</w>': 128,
#  'ن ل و م و ك ش</w>': 1,
#  '،</w>': 105,
#  'خ دا م</w>': 611,
#  'بالك و م بي و ت ر</w>': 2,
#  'عن د ك</w>': 2914,
#  'كا و كا و</w>': 4,
#  'ل و ز </w>': 3,
#  'نا ك ل و</w>': 100,
#  'أ ت ا ي ؟</w>': 36,
#  'ن في ري في</w>': 19,
#  'الص و ل د</w>': 57,
#  'كا ن</w>': 806,
#  'م م ل</w>': 64,
#  'شو ي ة ،</w>': 461,
#  'كنت</w>': 803,
#  'ن ع س</w>': 173,
#  'را س ي</w>': 721,
#  'ت ق ل و</w>': 2,
#  'ب حال</w>': 627,
#  'الح و لي</w>': 68,
#  'م س ح</w>': 16,
#  'ال غ ب رة</w>': 110,
#  'ف و ق</w>': 177,
#  'الت ل ف ز ي ون</w>': 64,
#  'كت خ ل ص </w>': 326,
#  'ال ض ما ن</w>': 17,
#  'الا ج ت ما ع ي ؟</w>': 12,
#  'ن دي روا</w>': 61,
#  'بال ن عنا ع</w>': 120,
#  'ب شحال</w>': 571,
#  'كت ح س ب</w>': 30,
#  'الكي ل و م ت ر ؟</w>': 6,
#  'كت س الي</w>': 14,
#  'الم ق ا ب ل ة</w>': 20,
#  'بالم ع ط ى</w>': 1,
#  'كنت ري ني</w>': 30,
#  'ن ن ج ح</w>': 31,
#  'فالت ي س ت</w>': 1,
#  'نت فا ه م و</w>': 22,
#  'ما ن و ق ع و ش</w>': 4,
#  'فالم ش ا ك ل</w>': 14,
#  'الط لا ق</w>': 17,
#  'دو ر</w>': 141,
#  'ن ش ر</w>': 19,
#  'مزيا ن ة</w>': 1077,
#  'الم غ ر ب ؟</w>': 129,
#  'خ و ك</w>': 43,
#  'الك بي ر</w>': 120,
#  'كي م شي</w>': 114,
#  'ي دي ر</w>': 404,
#  'ش ه ر</w>': 52,
#  'ح س ا ب</w>': 154,
#  'م ر ض </w>': 34,
#  'لي</w>': 4545,
#  'ب را كا</w>': 7,
#  'الس ك ر ،</w>': 31,
#  'م ض ر</w>': 22,
#  'لل ص ح ة</w>': 134,
#  'ن س ي ت</w>': 292,
#  'الم و د با س</w>': 88,
#  'ال إ ي م ي ل ،</w>': 3,
#  'ن ص ي ف ط </w>': 143,
#  'لل ش ر ك ة</w>': 13,
#  'ي رج ع و ه</w>': 1,
#  'الم و س ي ق ى</w>': 298,
#  'ه ي</w>': 936,
#  'الم ت ن ف س</w>': 1,
#  'ك ل شي</w>': 1444,
#  'كي ك ذ ب</w>': 28,
#  'ن ر ك ب</w>': 188,
#  'ال خ ي ل</w>': 163,
#  'الت ري د</w>': 6,
#  'ال ع ش ا ء </w>': 48,
#  'الت ي لي ف ون</w>': 1506,
#  'كا م ي را</w>': 90,
#  'وا عرة</w>': 899,
#  'نت</w>': 7,
#  'ت ح ر ك</w>': 17,
#  'فال ر ق ص </w>': 5,
#  'الش ر ق ي ؟</w>': 11,
#  'كت ق را</w>': 251,
#  'كت ب ؟</w>': 1,
#  'م خاص ن ي ش</w>': 11,
#  'الس خ آ ن أ </w>': 1,
#  'و ج ه ي ؟</w>': 5,
#  'با ق ى</w>': 31,
#  'ها دي ؟</w>': 129,
#  'ش ر ب</w>': 166,
#  'كا س</w>': 317,
#  'أ ت ا ي</w>': 380,
#  'س خ ون</w>': 259,
#  'بال ن عنا ع ،</w>': 15,
#  'غا ي س ر ح ك</w>': 1,
#  'نق ط ع</w>': 253,
#  'الط ري ف</w>': 4,
#  'ال ف ر ما ج </w>': 19,
#  'نا م و س ية</w>': 27,
#  'ج دي د ة ،</w>': 100,
#  'ظ ه ري</w>': 78,
#  'ض ر ني</w>': 305,
#  'ن ع ي ط </w>': 160,
#  'لي ك</w>': 1741,
#  'ال وا ت س ا ب</w>': 268,
#  'م ني</w>': 261,
#  'نت س الي</w>': 2,
#  'م ج ال</w>': 74,
#  'ال إ علا م</w>': 31,
#  'الس لا م</w>': 70,
#  'علي ك م ،</w>': 26,
#  'ن س و ل ك</w>': 134,
#  'حا ج ة؟</w>': 144,
#  'كنق ل ب</w>': 570,
#  'ي عل م ني</w>': 33,
#  'الم ونت ا ج </w>': 29,
#  'ال في دي و</w>': 278,
#  'ن و لي</w>': 144,
#  'ي و ت ي و ب ر</w>': 8,
#  'ش عل</w>': 121,
#  'ال ض و</w>': 833,
#  'ال ض لا م</w>': 21,
#  'الح ل و ة</w>': 179,
#  'م ع س ل ة</w>': 3,
#  'ال ز ي ت ون</w>': 146,
#  'ك ح ل</w>': 29,
#  'الب ر د</w>': 279,
#  'د خ ل</w>': 55,
#  'لل دا ر</w>': 159,
#  'ن س دو</w>': 12,
#  'الش را ج م</w>': 96,
#  'بالس لا م ة ،</w>': 5,
#  'ت ه لا</w>': 75,
#  'ف را س ك</w>': 109,
#  'شو ف</w>': 1309,
#  'ال ف را ش ة</w>': 30,
#  'ش ن و</w>': 3560,
#  'ال ه ن د س ة</w>': 58,
#  'ال و را ث ي ة؟</w>': 38,
#  'ال د ن يا</w>': 864,
#  'ص غي رة</w>': 303,
#  'ب ف ض ل</w>': 78,
#  'الت كن و ل و ج يا</w>': 145,
#  'الج دي د ة</w>': 430,
#  'الم عل و ما ت</w>': 201,
#  'ق ل تي</w>': 104,
#  'ص ع ي بة</w>': 789,
#  'م ت أ ك د</w>': 52,
#  'م ن ها ؟</w>': 40,
#  'ال عل ما ء </w>': 190,
#  'كي ت نا ف س و</w>': 35,
#  'بي نا ت ه م</w>': 49,
#  'ي كت ش ف</w>': 32,
#  'ج دي د ة</w>': 1105,
#  'الق م ر</w>': 42,
#  'الص نا ع ي</w>': 37,
#  'كي دو ر</w>': 101,
#  'ال أ ر ض </w>': 284,
#  'الا م را ض </w>': 39,
#  'كي ل ق ا و</w>': 56,
#  'لي ه م</w>': 164,
#  'ال دوا</w>': 402,
#  'نق را و</w>': 112,
#  'ال عل و م</w>': 551,
#  'ن ك ون و</w>': 150,
#  'م س ت ع دين</w>': 39,
#  'لل م س ت ق ب ل</w>': 68,
#  'ها د شي</w>': 1149,
#  'كت ش ر ح</w>': 60,
#  'لي ه</w>': 736,
#  'كي د خ ل</w>': 96,
#  'لل د ما غ </w>': 36,
#  'بال ز ز ،</w>': 37,
#  'وال و</w>': 1706,
#  'ال ف ل و س ،</w>': 96,
#  'إ لا</w>': 99,
#  'ق ري ت ي ها</w>': 40,
#  'ت ر ب ح</w>': 173,
#  'البي ئ ة</w>': 155,
#  'ديال نا</w>': 1346,
#  'كت م ر ض </w>': 82,
#  'ب س با ب</w>': 75,
#  'الت ل و ث ،</w>': 37,
#  'ي ح ف ظ </w>': 130,
#  'ن ب دا و</w>': 108,
#  'ن را ج ع و</w>': 43,
#  'ال د ر س</w>': 183,
#  'كا م ل</w>': 442,
#  'يا ك ما</w>': 630,
#  'ن ع س تي</w>': 59,
#  'فالح ص ة</w>': 41,
#  'ما م ت ب ع ش</w>': 39,
#  'م عا نا ؟</w>': 49,
#  'ه ز </w>': 66,
#  'ت ي لي ف ون ك</w>': 19,
#  'كن ع ي ط </w>': 4,
#  'ل ك</w>': 305,
#  'كا ي ع ج ب ني</w>': 18,
#  'ن ف رج </w>': 3,
#  'ال ع ص ا ف ر</w>': 4,
#  'ال نت ي ج ة؟</w>': 11,
#  'أ ر ض </w>': 64,
#  'ال ن وا ح ي</w>': 6,
#  'م را ك ش</w>': 105,
#  'ال و را ق</w>': 116,
#  'البي ع</w>': 193,
#  'والش را</w>': 62,
#  'وا ج دي ن ؟</w>': 11,
#  'ال أ ك ل ة</w>': 14,
#  'كت ج ي</w>': 88,
#  'ب ن ي ن ة</w>': 109,
#  'الك م ون</w>': 8,
#  'كنت ف رج </w>': 204,
#  'ف ك ل شي</w>': 18,
#  'ش ا ه د</w>': 13,
#  'دو ز ت</w>': 125,
#  'الس ه رة</w>': 23,
#  'ف س ي ن ما ،</w>': 1,
#  'ض ر ب ت</w>': 102,
#  'ال أ ك ش ن</w>': 13,
#  'أ م ي</w>': 7,
#  'كت ع ج ب ها</w>': 17,
#  'ت خ د م</w>': 238,
#  'الك رو شي</w>': 21,
#  'ن ش ري</w>': 2043,
#  'ت ذ كا رية</w>': 1,
#  'لل م غ ر ب</w>': 23,
#  'ال دا ر</w>': 2664,
#  'خاص ها</w>': 576,
#  'الا ص لا ح</w>': 7,
#  'ت و لي</w>': 117,
#  'ص ع ي ب</w>': 822,
#  'ت ج م ع</w>': 26,
#  'ك و م ي ونتي</w>': 7,
#  'كا نت ش</w>': 13,
#  'ف ك رة</w>': 277,
#  'كي</w>': 996,
#  'ج ا ت ك</w>': 357,
#  'الط و م و بي ل</w>': 1462,
#  'الج دي د ة؟</w>': 149,
#  'ز و ي ن ة؟</w>': 37,
#  'د خ ل ت</w>': 46,
#  'ل دا ك</w>': 10,
#  'الم نت د ى</w>': 258,
#  'ليا ،</w>': 216,
#  'كي با ن</w>': 215,
#  'ز و ين</w>': 603,
#  'كت نق ص </w>': 13,
#  'ب ع د</w>': 459,
#  'الم را ت ؟</w>': 1,
#  'ال خ با ر</w>': 263,
#  'خ لا ت ني</w>': 20,
#  'م غ و ب ش</w>': 8,
#  'ن ش ا ر ك</w>': 131,
#  'ف وا ح د</w>': 213,
#  'الك رو ب</w>': 605,
#  'الم غا ر بة</w>': 236,
#  'عا ي ش ين</w>': 85,
#  'فال خا رج </w>': 40,
#  'آ ش</w>': 1242,
#  'س م ي ت</w>': 25,
#  'الك ونت</w>': 79,
#  'ديالك</w>': 1444,
#  'ف ت و ي ت ر ؟</w>': 1,
#  'ك و م ون د</w>': 4,
#  'ن س الي ه م</w>': 2,
#  'الس ي ما ن ة</w>': 243,
#  'الب و ط ا ج ي</w>': 18,
#  'خ ص و</w>': 128,
#  'ي ت غ س ل</w>': 13,
#  'الج ا ج ة</w>': 33,
#  'ال في س ب و ك</w>': 203,
#  'و لي تي</w>': 89,
#  'ت ت شو ف</w>': 3,
#  'ال أ يا م</w>': 399,
#  'ت و ص ل</w>': 179,
#  'ح ت ى</w>': 1350,
#  'ل م را ك ش ؟</w>': 64,
#  'فين</w>': 7387,
#  'ق ري تي</w>': 328,
#  'و ص ل تي</w>': 188,
#  'ل هاد</w>': 476,
#  'الم ن ص ب ؟</w>': 2,
#  'ن ص ل ح</w>': 181,
#  'ه نا ؟</w>': 937,
#  'ب ب غا ء </w>': 11,
#  'كي ه ض ر</w>': 310,
#  'كن بغي</w>': 351,
#  'فالت ل فا ز ة</w>': 59,
#  'ال ع ش ية</w>': 148,
#  'الك ون ي ك س ي ون ،</w>': 36,
#  'ت و ري ني</w>': 49,
#  'فال خ ري ط ة</w>': 2,
#  'كي فاش</w>': 1529,
#  'ن م ش ي ؟</w>': 34,
#  'ب ح ث </w>': 69,
#  'الس و ق</w>': 462,
#  'ما ن ب دا و</w>': 12,
#  'الم ش رو ع</w>': 316,
#  'س خاصني</w>': 9,
#  'ن ب د ل</w>': 1319,
#  'الس ت ا ي ل</w>': 48,
#  'ي ع ط ي</w>': 14,
#  'الص ح ة</w>': 588,
#  'الل عا ب</w>': 141,
#  'ب دي تي</w>': 55,
#  'ري ج ي م</w>': 37,
#  'ج دي د ؟</w>': 129,
#  'علي ك ،</w>': 359,
#  'ا ح ت ر م و</w>': 1,
#  'ن س ج ل</w>': 150,
#  'فاللا ئ ح ة</w>': 3,
#  'دال إ نت ظ ا ر</w>': 1,
#  'دا ي رة</w>': 403,
#  'ج ه د ها</w>': 5,
#  'ت ص ل ح</w>': 106,
#  'الت علي م</w>': 134,
#  'الما ع ز </w>': 33,
#  'كي ط ل ع</w>': 33,
#  'لل ج ب ل</w>': 11,
#  'ب ك ل</w>': 36,
#  'س ه و ل ة</w>': 1,
#  'كت ج ري</w>': 37,
#  'ليا ما ت ؟</w>': 5,
#  'ع يا ت</w>': 38,
#  'ت م شي</w>': 346,
#  'عن د</w>': 595,
#  'الط بي ب ،</w>': 24,
#  'ل ق ا ت</w>': 4,
#  'دوا</w>': 181,
#  'ب نتي</w>': 213,
#  'خا ف ت</w>': 11,
#  'بزا ا ف</w>': 92,
#  'الط بي ب</w>': 291,
#  'الي و م</w>': 1452,
#  'الت ي لي ف ونا ت</w>': 83,
#  'مزيا ن ؟</w>': 609,
#  'كت ف ه م</w>': 82,
#  'ي م كن</w>': 387,
#  'ن ل ق ا</w>': 253,
#  'الق ا ي د</w>': 12,
#  'الم ن ط ق ة؟</w>': 75,
#  'س م ع تي</w>': 306,
#  'البا ر ح ؟</w>': 217,
#  'ن س ي تي</w>': 58,
#  'لي كي ب</w>': 13,
#  'د ق ا ت</w>': 2,
#  'لي ك م</w>': 20,
#  'ال عا م</w>': 1046,
#  'فا ت</w>': 115,
#  'ب خ م س ة</w>': 1,
#  'البي لا نت يا ت ؟</w>': 1,
#  'ما عن د ك</w>': 20,
#  'الص ر ف</w>': 230,
#  'ل خ م س ين</w>': 5,
#  'د ر ه م ؟</w>': 36,
#  'ح ط ي تي</w>': 323,
#  'الح وا ي ج </w>': 139,
#  'ي ت ش م شو</w>': 2,
#  'فالس ط ح ؟</w>': 8,
#  'الم و د</w>': 179,
#  'با س و و ر د</w>': 4,
#  'ال في س ب و ك ،</w>': 31,
#  'كي ت س ر ق</w>': 1,
#  'عا شو را ء </w>': 1,
#  'م ب رو ك</w>': 26,
#  'ه ذ ا ك</w>': 552,
#  'م ن و</w>': 249,
#  'ش ف ت</w>': 251,
#  'ال ذ ئ ب</w>': 7,
#  'فال غا بة</w>': 28,
#  'ج ا ن با</w>': 1,
#  'ش غ ل</w>': 82,
#  'الب غ ل ة</w>': 7,
#  'ت ع ي ش</w>': 77,
#  'ح يا ت ك</w>': 49,
#  'كي ما</w>': 24,
#  'بغي تي</w>': 498,
#  'ا نت</w>': 34,
#  'ت ذ ك رة</w>': 164,
#  'البي ض ا ء ،</w>': 10,
#  'ذ ها ب</w>': 57,
#  'و إ يا ب</w>': 25,
#  'الم و دي م ،</w>': 16,
#  'ه ذ ا</w>': 1478,
#  'ق دي م</w>': 226,
#  'كن م شي</w>': 227,
#  'نت ڭ د ى</w>': 3,
#  'فالس و ق</w>': 94,
#  'أ ح د ،</w>': 1,
#  'ض رو ري</w>': 1145,
#  'را ك</w>': 1772,
#  'م ف ل ك س ة</w>': 1,
#  'كت ر</w>': 75,
#  'ا نا</w>': 213,
#  'ي س ت ر ،</w>': 118,
#  'ك ل ها</w>': 308,
#  'كا م ي ونا ت</w>': 2,
#  'الق ط </w>': 277,
#  'كي ل ح س</w>': 1,
#  'رج لي ه</w>': 9,
#  'ي نق ي</w>': 3,
#  'را س و</w>': 179,
#  'ع با ية</w>': 8,
#  'م غ ر بية</w>': 71,
#  'و لي ت</w>': 187,
#  'م د من</w>': 124,
#  'ال أ ل عا ب</w>': 96,
#  'الالكت رون ي ة ،</w>': 2,
#  'كن س ه ر</w>': 5,
#  'باللي ل</w>': 429,
#  'الص با غ ة</w>': 256,
#  'الط و م و بي ل ؟</w>': 221,
#  'فالت ي لي ف ون ؟</w>': 19,
#  'كي ع ج ب ني</w>': 782,
#  'ال ز ر ز و ر</w>': 8,
#  'كي ز ق ز ق</w>': 4,
#  'فالص با ح</w>': 88,
#  'ط ل عا ت</w>': 53,
#  'ق ا ن ون</w>': 244,
#  'ج دي د</w>': 1142,
#  'الس ي ر ،</w>': 6,
#  'كي ت با ع</w>': 164,
#  'ال خ ب ز </w>': 401,
#  'حا ض ي</w>': 52,
#  'ال ها ك ر ز ،</w>': 1,
#  'ك ث رة</w>': 99,
#  'الس ر ق ة</w>': 38,
#  'فال أ نت ر ن ي ت</w>': 56,
#  'كا ين</w>': 3716,
#  'ت خ في ض ا ت</w>': 46,
#  'فالط يا رة</w>': 11,
#  'ال و ق ت ؟</w>': 92,
#  'الك ل ما ت</w>': 76,
#  'ال أ غ ن ية</w>': 169,
#  'م ؤ ث رة</w>': 28,
#  'ال إ ق ا م ة؟</w>': 9,
#  'كت س ج ل تي</w>': 4,
#  'دي ك</w>': 543,
#  'ل ڭ رو پ </w>': 25,
#  'ل م غا ر بة</w>': 1,
#  'أ ل ما ن يا ؟</w>': 4,
#  'ق الك</w>': 142,
#  'الم ح ك مة</w>': 240,
#  'ع ط ا ت و</w>': 5,
#  'الب را ء ة</w>': 2,
#  'ال ع دال ة</w>': 49,
#  'ب ط ي ئ ة</w>': 9,
#  'ه و ما</w>': 36,
#  'أ ح س ن</w>': 342,
#  'ك رو با ت</w>': 14,
#  'فال في س ب و ك ؟</w>': 16,
#  'ق ال وا</w>': 118,
#  'فالت ل ف ز ة</w>': 78,
#  'غ لا ء </w>': 12,
#  'ال أ س عا ر</w>': 98,
#  'ط عن</w>': 10,
#  'الق را ر</w>': 95,
#  'ال إ دا ري ؟</w>': 3,
#  'ك ث ر تي</w>': 38,
#  'ال ه ض رة</w>': 437,
#  'ال فا ي س ب و ك</w>': 46,
#  'ط ا ح</w>': 384,
#  'الش ا رج </w>': 74,
#  'الق ه و ة</w>': 239,
#  'نت ف رج و</w>': 156,
#  'كنت س نا</w>': 64,
#  'الا ي م ي ل</w>': 17,
#  'نا ك د</w>': 1,
#  'الت س ج ي ل</w>': 30,
#  'ي س م ح</w>': 247,
#  'لي نا</w>': 877,
#  'كن ح ر ك ب و</w>': 1,
#  'ال ن م ل</w>': 60,
#  'ب لا</w>': 341,
#  'ن ح س</w>': 30,
#  'البيا س ة</w>': 36,
#  'غالية</w>': 366,
#  'نا ك ل</w>': 339,
#  'ط ن ج ية</w>': 7,
#  'م را ك ش ي ة؟</w>': 3,
#  'ي ج ا ز ي ك م</w>': 4,
#  'بال خ ي ر ،</w>': 50,
#  'عا ون وني</w>': 5,
#  'ن ل ق ى</w>': 881,
#  'دا ك</w>': 581,
#  'ال پ و س ت</w>': 3,
#  'ت ق ال</w>': 26,
#  'الك لا م</w>': 66,
#  'ال ڭ رو ب</w>': 66,
#  'نت ق د ى</w>': 93,
#  'ب ص را ح ة</w>': 48,
#  'كي ل ع ب</w>': 249,
#  'الا</w>': 43,
#  'فال د ر ب</w>': 8,
#  'ه و</w>': 1272,
#  'ال</w>': 293,
#  'الش ر ك ة؟</w>': 72,
#  'نت ص ل</w>': 55,
#  'ب ه م</w>': 4,
#  'الكا ر ط </w>': 72,
#  'في ز ي ت</w>': 51,
#  'الي و م ،</w>': 312,
#  'نق د ر ؟</w>': 1,
#  'ي خ لي ك</w>': 546,
#  'ت ل ع ب</w>': 348,
#  'ب شو ي ة ،</w>': 32,
#  'غا ت ه ر س</w>': 1,
#  'الي د</w>': 37,
#  'ي ع ط ي ك</w>': 442,
#  'ال ه دية</w>': 4,
#  'الكت ا ب ،</w>': 172,
#  'ف ر ح ت ي ني</w>': 2,
#  'ق ل ب ت</w>': 62,
#  'خ د مة</w>': 823,
#  'مالق ي ت ش</w>': 168,
#  'ن خ د م و</w>': 65,
#  'ال ن ية</w>': 52,
#  'ي با ر ك</w>': 189,
#  'ال خ دا مة</w>': 51,
#  'عن د ها</w>': 584,
#  'ك فا ء ة</w>': 6,
#  'عالية</w>': 39,
#  'ت س نا ن ي ،</w>': 2,
#  'ن دو ش</w>': 14,
#  'ن ج ي ك</w>': 3,
#  'م و ل</w>': 526,
#  'الط ا ك س ي</w>': 316,
#  'خ لي نا</w>': 321,
#  'خ في ف ة</w>': 173,
#  'ب آ خ ر</w>': 7,
#  'دا رو</w>': 527,
#  'فالب ر ل ما ن ؟</w>': 4,
#  'ت ب ق ا و ش</w>': 19,
#  'ت ض غ ط و</w>': 1,
#  'ال ف را ن</w>': 232,
#  'ال رو ي ض </w>': 13,
#  'كي ت ز ل ق و</w>': 3,
#  'ي ش ا في ك ،</w>': 28,
#  'ي عا ون ك</w>': 561,
#  'م كا ي ن ش</w>': 110,
#  'الك ون ك س ي ون ،</w>': 2,
#  'كت ه ر س</w>': 5,
#  'ال ري ق</w>': 8,
#  'ت ل فا ز ة</w>': 25,
#  'س ما ر ت</w>': 16,
#  'ت ك ون</w>': 1236,
#  'ك بي رة</w>': 566,
#  'ال د رو ي ش</w>': 17,
#  'ع م روا</w>': 3,
#  'ما ي س كت ،</w>': 1,
#  'ي ش كي</w>': 10,
#  'ي ه دي ه م ،</w>': 22,
#  'كي دي رو</w>': 255,
#  'ح را م</w>': 81,
#  'ن و ج د</w>': 108,
#  'نق ن ع</w>': 1,
#  'الم س ت ث م رين</w>': 4,
#  'كن عل م</w>': 3,
#  'البا ر بي</w>': 2,
#  'ن ري ك لا م ي</w>': 2,
#  'ح ي ت</w>': 281,
#  'ما خ دا م ش</w>': 19,
#  'كا ي ج ي ني</w>': 43,
#  'نا خ د</w>': 174,
#  'فا ص مة</w>': 3,
#  'لل را س ي</w>': 1,
#  'م نا س بة</w>': 37,
#  'عا ر ف</w>': 766,
#  'كت ا ب</w>': 745,
#  'الط ب خ </w>': 189,
#  'الم غ ر بي</w>': 163,
#  'س م ح</w>': 237,
#  'لي ،</w>': 45,
#  'ما بغي ت ش</w>': 194,
#  'ن د خ ل</w>': 422,
#  'ف شي</w>': 529,
#  'كا ت عن ي ش</w>': 1,
#  'خ دي تي</w>': 43,
#  'ال فا ك س ا ن</w>': 9,
#  'ك و في د ؟</w>': 3,
#  'الم رة</w>': 224,
#  'حا د ك ة</w>': 10,
#  'ي خ لي ك ،</w>': 232,
#  'ع ش رين</w>': 12,
#  'عا م</w>': 111,
#  'ب ق اش</w>': 235,
#  'فيا</w>': 232,
#  'ن ح ض ر</w>': 35,
#  'الح ف ل</w>': 6,
#  'الم و س ي ق ي</w>': 6,
#  'كن ل ع ب</w>': 207,
#  'الص با ح ،</w>': 26,
#  'ما ن ع س ت ش</w>': 3,
#  'ت عر ف</w>': 287,
#  'الج وا ب</w>': 25,
#  'كي ق و ل و</w>': 276,
#  'ت ا خ د</w>': 73,
#  'إ ج را ء ا ت</w>': 12,
#  'ص ا ر مة</w>': 9,
#  'و ت ف ر ق ع ت</w>': 1,
#  'الك رون ة</w>': 2,
#  'ما ر ك ة</w>': 100,
#  'الما كيا ج ؟</w>': 50,
#  'دا ي ر</w>': 594,
#  'الص ا ك</w>': 44,
#  'الج دي د ؟</w>': 217,
#  'ت حا ر ب</w>': 52,
#  'ال ف س ا د</w>': 151,
#  'الط ر ق</w>': 14,
#  'ب دي ت</w>': 77,
#  'ال إ ن ج لي ز ية</w>': 49,
#  'بال أ نت ر نت</w>': 5,
#  'كن ف ض ل</w>': 329,
#  'ال أ ف لا م</w>': 199,
#  'فال دا ر</w>': 348,
#  'الس ي ن ما</w>': 139,
#  'ع يا ت نا</w>': 3,
#  'بال و ع و د</w>': 2,
#  'ديال ها</w>': 192,
#  'وا خا</w>': 2081,
#  'غ ن با ر ط ا ج ي</w>': 1,
#  'الب و س ت</w>': 70,
#  'عن د ك عن د ك</w>': 3,
#  'البي س ي</w>': 706,
#  'ص دا ع ؟</w>': 10,
#  'ج ا</w>': 252,
#  'ال ض ي ف</w>': 5,
#  'ن ح م ر</w>': 2,
#  'و ج ه ي</w>': 229,
#  'م ش ك ل</w>': 543,
#  'غ را في ك</w>': 3,
#  'ن س د</w>': 25,
#  'الم خ ب ز ة</w>': 44,
#  'خ لي ك</w>': 112,
#  'م ت وا ض ع</w>': 8,
#  'ي س ه ل</w>': 711,
#  'كن د ر ب</w>': 1,
#  'ال ر ك بة</w>': 1,
#  'دي ر</w>': 997,
#  'ح ر ك ة</w>': 8,
#  'ت لا ح</w>': 14,
#  'ال ع يا</w>': 35,
#  'ن دي</w>': 147,
#  'لل ط بي ب</w>': 69,
#  'البي ط ري</w>': 105,
#  'ي ج ي ب</w>': 232,
#  'ي ف ه م</w>': 49,
#  'الس يا س ة</w>': 299,
#  'الق ا ع ة</w>': 14,
#  'كا نت</w>': 359,
#  'عا م رة</w>': 263,
#  'بال نا س</w>': 96,
#  'ها دي</w>': 1568,
#  'ت لا ق ي نا</w>': 4,
#  'خاص </w>': 908,
#  'ي ح ت ر م</w>': 14,
#  'الم نا ف س</w>': 5,
#  'ال د ري</w>': 109,
#  'ص ا ح بي</w>': 468,
#  'س ا كن</w>': 106,
#  'ح دا يا</w>': 30,
#  'خ ص ك</w>': 393,
#  'دالس ك ر</w>': 3,
#  'الق ه و ة؟</w>': 39,
#  'ن و ج دو</w>': 55,
#  'ال عر ض </w>': 53,
#  'الت ق ني</w>': 39,
#  'ن د ف ع و ه</w>': 1,
#  'لل م نا ق ص ة</w>': 1,
#  'مال</w>': 696,
#  'الس ي د ة</w>': 44,
#  'م ز ي رة</w>': 24,
#  'الي و م ؟</w>': 759,
#  'مزيا ن ة؟</w>': 196,
#  'الم ل ف</w>': 46,
#  'ال أ س ا ت ذ ة</w>': 9,
#  'الم ت د ر بي ن ؟</w>': 2,
#  ...}

# %%
encoder.save("assets/models/BPE.pkl")
# Out:
# BPE model saved to assets/models/BPE.pkl

# %%
bpe = BytePairEncoding()
bpe.load("assets/models/BPE.pkl") 

tokens = bpe.encode("خاصني نتعلم باش نخدم")
print(tokens)
# Out:
# BPE model loaded from assets/models/BPE.pkl
# ['خاصني</w>', 'نت', 'عل', 'م</w>', 'ب', 'اش</w>', 'ن', 'خ', 'د', 'م</w>']
